# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
#from google.colab.patches import cv2_imshow
import glob

# %%
#applying filter on a single image
def apply_filter(filename,filter):

  print("reading file---> "+str(filename))
  img=cv2.imread(filename,cv2.IMREAD_GRAYSCALE)
  
  img=cv2.resize(img,(250,250))  
  #comment out the above line if there is memory issue i.e. need to resize all images to smaller dim

  h, w = img.shape
  print("shape: "+str(h)+" x "+str(w)+"\n")
  # define filters
  horizontal = filter
  vertical = np.transpose(filter)

  # define images with 0s
  newhorizontalImage = np.zeros((h, w))
  newverticalImage = np.zeros((h, w))
  newgradientImage = np.zeros((h, w))

  # offset by 1
  for i in range(1, h - 1):
      for j in range(1, w - 1):
          horizontalGrad = (horizontal[0, 0] * img[i - 1, j - 1]) + \
                          (horizontal[0, 1] * img[i - 1, j]) + \
                          (horizontal[0, 2] * img[i - 1, j + 1]) + \
                          (horizontal[1, 0] * img[i, j - 1]) + \
                          (horizontal[1, 1] * img[i, j]) + \
                          (horizontal[1, 2] * img[i, j + 1]) + \
                          (horizontal[2, 0] * img[i + 1, j - 1]) + \
                          (horizontal[2, 1] * img[i + 1, j]) + \
                          (horizontal[2, 2] * img[i + 1, j + 1])

          newhorizontalImage[i - 1, j - 1] = abs(horizontalGrad)

          verticalGrad = (vertical[0, 0] * img[i - 1, j - 1]) + \
                        (vertical[0, 1] * img[i - 1, j]) + \
                        (vertical[0, 2] * img[i - 1, j + 1]) + \
                        (vertical[1, 0] * img[i, j - 1]) + \
                        (vertical[1, 1] * img[i, j]) + \
                        (vertical[1, 2] * img[i, j + 1]) + \
                        (vertical[2, 0] * img[i + 1, j - 1]) + \
                        (vertical[2, 1] * img[i + 1, j]) + \
                        (vertical[2, 2] * img[i + 1, j + 1])

          newverticalImage[i - 1, j - 1] = abs(verticalGrad)

          # Edge Magnitude
          mag = np.sqrt(pow(horizontalGrad, 2.0) + pow(verticalGrad, 2.0))
          newgradientImage[i - 1, j - 1] = mag

  return newgradientImage

# %%
def convert_edge_dir(sourcedir,destdir):
  print("\n\n---reading directory "+sourcedir+"---\n")
  filecnt=1 
  num=0
  if not os.path.isdir( destdir ) :
    os.mkdir( destdir )
  for filename in glob.glob(sourcedir+'/*'):
  	#applying Prewitt filter
  	#for appyling any other filter change filter value accordingly i.e. the 2nd args for apply_filter()
    imagemat=apply_filter(filename,np.array([[-1,0,1],[-1,0,1],[-1,0,1]]))
    if not cv2.imwrite(destdir+'/img-'+str(filecnt)+'.png',imagemat):
     raise Exception("Could not write image")
    #cv2.imwrite(destdir+'/img-'+str(filecnt)+'.png',imagemat) #create the edge image and store it to consecutive filenames
    filecnt+=1
    num+=1
    print(num)
  print("\n\n--saved in "+destdir+"--\n")

# %%
#function for creating all edge-images under both covid and non-covid directories 
#since 2-class so COVID and NON-COVID present
def convert_edge_all_dir(coviddir,ncoviddir,pnemoniadir,destdir):
	
  convert_edge_dir(coviddir,destdir+r'/COVID')
  convert_edge_dir(ncoviddir,destdir+r'/NON-COVID')
  convert_edge_dir(pnemoniadir,destdir+r'/Pnemonia')
  print("\n---edge detection completed--\n")

# %%
#adjust the source paths accordingly
coviddir=r"C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid" #source path for covid dir
ncoviddir=r"C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid" #source path for non-covid dir
pnemoniadir=r"C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia" #source path for pnemonia dir

# %%
#adjust the destination directory accordingly
#directory naming format--> <dataset_name(not necessary conventional)>_edge/<filtername>
destdir=r'C:/Users/hvard/Desktop/Project/EdgeDetectedImages_Test'

# %%
convert_edge_all_dir(coviddir,ncoviddir,pnemoniadir,destdir)
# Out:
# ---reading directory C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid---
#
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_10.png
# shape: 250 x 250
#
# 1
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_11.png
# shape: 250 x 250
#
# 2
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_2.png
# shape: 250 x 250
#
# 3
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_3.png
# shape: 250 x 250
#
# 4
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_4.png
# shape: 250 x 250
#
# 5
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_5.png
# shape: 250 x 250
#
# 6
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_6.png
# shape: 250 x 250
#
# 7
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_7.png
# shape: 250 x 250
#
# 8
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_8.png
# shape: 250 x 250
#
# 9
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Comparison-of-different-samples-for-2019-novel-cor_2020_International-Journa-p2-21_9.png
# shape: 250 x 250
#
# 10
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-1.png
# shape: 250 x 250
#
# 11
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-10.png
# shape: 250 x 250
#
# 12
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-11.png
# shape: 250 x 250
#
# 13
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-12.png
# shape: 250 x 250
#
# 14
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-13.png
# shape: 250 x 250
#
# 15
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-14.png
# shape: 250 x 250
#
# 16
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-15.png
# shape: 250 x 250
#
# 17
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-16.png
# shape: 250 x 250
#
# 18
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-17.png
# shape: 250 x 250
#
# 19
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-18.png
# shape: 250 x 250
#
# 20
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-19.png
# shape: 250 x 250
#
# 21
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-2.png
# shape: 250 x 250
#
# 22
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-20.png
# shape: 250 x 250
#
# 23
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-21.png
# shape: 250 x 250
#
# 24
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-22.png
# shape: 250 x 250
#
# 25
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-23.png
# shape: 250 x 250
#
# 26
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-24.png
# shape: 250 x 250
#
# 27
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-25.png
# shape: 250 x 250
#
# 28
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-26.png
# shape: 250 x 250
#
# 29
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-27.png
# shape: 250 x 250
#
# 30
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-28.png
# shape: 250 x 250
#
# 31
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-29.png
# shape: 250 x 250
#
# 32
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-3.png
# shape: 250 x 250
#
# 33
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-30.png
# shape: 250 x 250
#
# 34
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-31.png
# shape: 250 x 250
#
# 35
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-32.png
# shape: 250 x 250
#
# 36
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-33.png
# shape: 250 x 250
#
# 37
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-34.png
# shape: 250 x 250
#
# 38
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-35.png
# shape: 250 x 250
#
# 39
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-36.png
# shape: 250 x 250
#
# 40
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-37.png
# shape: 250 x 250
#
# 41
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-38.png
# shape: 250 x 250
#
# 42
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-39.png
# shape: 250 x 250
#
# 43
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-4.png
# shape: 250 x 250
#
# 44
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-40.png
# shape: 250 x 250
#
# 45
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-41.png
# shape: 250 x 250
#
# 46
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-42.png
# shape: 250 x 250
#
# 47
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-43.png
# shape: 250 x 250
#
# 48
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-44.png
# shape: 250 x 250
#
# 49
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-45.png
# shape: 250 x 250
#
# 50
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-46.png
# shape: 250 x 250
#
# 51
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-47.png
# shape: 250 x 250
#
# 52
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-48.png
# shape: 250 x 250
#
# 53
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-49.png
# shape: 250 x 250
#
# 54
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-5.png
# shape: 250 x 250
#
# 55
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-50.png
# shape: 250 x 250
#
# 56
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-6.png
# shape: 250 x 250
#
# 57
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-7.png
# shape: 250 x 250
#
# 58
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-8.png
# shape: 250 x 250
#
# 59
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\COVID-9.png
# shape: 250 x 250
#
# 60
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\ehaa254-p0-63_2.png
# shape: 250 x 250
#
# 61
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\ehaa254-p0-63_3.png
# shape: 250 x 250
#
# 62
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\impact_of_covid19_infection_on_pregnancy_outcomes_and_the_risk_of_maternaltoneonatal_intrapartum_transmission_of_covid19_during_natural_birth-p8-41_1.png
# shape: 250 x 250
#
# 63
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\impact_of_covid19_infection_on_pregnancy_outcomes_and_the_risk_of_maternaltoneonatal_intrapartum_transmission_of_covid19_during_natural_birth-p8-41_3.png
# shape: 250 x 250
#
# 64
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\impact_of_covid19_infection_on_pregnancy_outcomes_and_the_risk_of_maternaltoneonatal_intrapartum_transmission_of_covid19_during_natural_birth-p8-41_5.png
# shape: 250 x 250
#
# 65
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e24-p2-8.png
# shape: 250 x 250
#
# 66
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e24-p3-16.png
# shape: 250 x 250
#
# 67
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e24-p5-29.png
# shape: 250 x 250
#
# 68
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e24-p5-31.png
# shape: 250 x 250
#
# 69
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e25-p1-10.png
# shape: 250 x 250
#
# 70
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e25-p1-12.png
# shape: 250 x 250
#
# 71
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e25-p1-14.png
# shape: 250 x 250
#
# 72
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e25-p1-6.png
# shape: 250 x 250
#
# 73
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\kjr-21-e25-p1-8.png
# shape: 250 x 250
#
# 74
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\med-9780198814924-chapter-17-p10-515.png
# shape: 250 x 250
#
# 75
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Ni2020_Article_CombinationOfWesternMedicineAn-p3-10_0.png
# shape: 250 x 250
#
# 76
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Ni2020_Article_CombinationOfWesternMedicineAn-p3-10_1.png
# shape: 250 x 250
#
# 77
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Ni2020_Article_CombinationOfWesternMedicineAn-p4-13_0.png
# shape: 250 x 250
#
# 78
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Ni2020_Article_CombinationOfWesternMedicineAn-p4-13_1.png
# shape: 250 x 250
#
# 79
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620301549_0_0.png
# shape: 250 x 250
#
# 80
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620301549_0_1.png
# shape: 250 x 250
#
# 81
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620301549_1.png
# shape: 250 x 250
#
# 82
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620301549_2.png
# shape: 250 x 250
#
# 83
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620302117_1.png
# shape: 250 x 250
#
# 84
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620302117_2.png
# shape: 250 x 250
#
# 85
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_0.png
# shape: 250 x 250
#
# 86
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_1.png
# shape: 250 x 250
#
# 87
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_2.png
# shape: 250 x 250
#
# 88
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_3.png
# shape: 250 x 250
#
# 89
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_4.png
# shape: 250 x 250
#
# 90
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_5.png
# shape: 250 x 250
#
# 91
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_6.png
# shape: 250 x 250
#
# 92
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_7.png
# shape: 250 x 250
#
# 93
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\PIIS0140673620303603_8.png
# shape: 250 x 250
#
# 94
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Recurrence-of-positive-SARS-CoV-2-RNA-in-C_2020_International-Journal-of-Inf-p1-21_0.png
# shape: 250 x 250
#
# 95
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Recurrence-of-positive-SARS-CoV-2-RNA-in-C_2020_International-Journal-of-Inf-p1-21_1.png
# shape: 250 x 250
#
# 96
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12_0.png
# shape: 250 x 250
#
# 97
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12_1.png
# shape: 250 x 250
#
# 98
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12_2.png
# shape: 250 x 250
#
# 99
# reading file---> C:/Users/hvard/Desktop/Project\Test_Covid\CT_Covid\Talaromyces-marneffei-infection-relapse-presenting-as-ost_2020_International-p1-12_3.png
# shape: 250 x 250
#
# 100
#
#
# --saved in C:/Users/hvard/Desktop/Project/EdgeDetectedImages_Test/COVID--
#
#
#
# ---reading directory C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid---
#
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1333.png
# shape: 250 x 250
#
# 1
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1335.png
# shape: 250 x 250
#
# 2
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1336.png
# shape: 250 x 250
#
# 3
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1428.png
# shape: 250 x 250
#
# 4
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1463.png
# shape: 250 x 250
#
# 5
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1497.png
# shape: 250 x 250
#
# 6
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1498.png
# shape: 250 x 250
#
# 7
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1499.png
# shape: 250 x 250
#
# 8
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1500.png
# shape: 250 x 250
#
# 9
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1501.png
# shape: 250 x 250
#
# 10
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1561.png
# shape: 250 x 250
#
# 11
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1562.png
# shape: 250 x 250
#
# 12
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1575.png
# shape: 250 x 250
#
# 13
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1576.png
# shape: 250 x 250
#
# 14
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1577.png
# shape: 250 x 250
#
# 15
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1638.png
# shape: 250 x 250
#
# 16
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1702.png
# shape: 250 x 250
#
# 17
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1814.png
# shape: 250 x 250
#
# 18
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1845.png
# shape: 250 x 250
#
# 19
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1846.png
# shape: 250 x 250
#
# 20
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1857.png
# shape: 250 x 250
#
# 21
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1858.png
# shape: 250 x 250
#
# 22
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1859.png
# shape: 250 x 250
#
# 23
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1868.png
# shape: 250 x 250
#
# 24
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1876.png
# shape: 250 x 250
#
# 25
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1877.png
# shape: 250 x 250
#
# 26
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1888.png
# shape: 250 x 250
#
# 27
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1889.png
# shape: 250 x 250
#
# 28
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1919.png
# shape: 250 x 250
#
# 29
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1920.png
# shape: 250 x 250
#
# 30
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1921.png
# shape: 250 x 250
#
# 31
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1922.png
# shape: 250 x 250
#
# 32
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1923.png
# shape: 250 x 250
#
# 33
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1924.png
# shape: 250 x 250
#
# 34
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\1952.png
# shape: 250 x 250
#
# 35
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2007.png
# shape: 250 x 250
#
# 36
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2039.png
# shape: 250 x 250
#
# 37
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2040.png
# shape: 250 x 250
#
# 38
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2041.png
# shape: 250 x 250
#
# 39
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2108.png
# shape: 250 x 250
#
# 40
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2138.png
# shape: 250 x 250
#
# 41
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2139.png
# shape: 250 x 250
#
# 42
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2140.png
# shape: 250 x 250
#
# 43
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2141.png
# shape: 250 x 250
#
# 44
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2142.png
# shape: 250 x 250
#
# 45
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2143.png
# shape: 250 x 250
#
# 46
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2144.png
# shape: 250 x 250
#
# 47
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2145.png
# shape: 250 x 250
#
# 48
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2237.png
# shape: 250 x 250
#
# 49
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\2341.png
# shape: 250 x 250
#
# 50
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-1.png
# shape: 250 x 250
#
# 51
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-10.png
# shape: 250 x 250
#
# 52
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-11.png
# shape: 250 x 250
#
# 53
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-12.png
# shape: 250 x 250
#
# 54
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-13.png
# shape: 250 x 250
#
# 55
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-14.png
# shape: 250 x 250
#
# 56
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-15.png
# shape: 250 x 250
#
# 57
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-16.png
# shape: 250 x 250
#
# 58
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-17.png
# shape: 250 x 250
#
# 59
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-18.png
# shape: 250 x 250
#
# 60
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-19.png
# shape: 250 x 250
#
# 61
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-2.png
# shape: 250 x 250
#
# 62
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-20.png
# shape: 250 x 250
#
# 63
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-21.png
# shape: 250 x 250
#
# 64
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-22.png
# shape: 250 x 250
#
# 65
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-23.png
# shape: 250 x 250
#
# 66
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-24.png
# shape: 250 x 250
#
# 67
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-25.png
# shape: 250 x 250
#
# 68
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-26.png
# shape: 250 x 250
#
# 69
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-27.png
# shape: 250 x 250
#
# 70
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-28.png
# shape: 250 x 250
#
# 71
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-29.png
# shape: 250 x 250
#
# 72
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-3.png
# shape: 250 x 250
#
# 73
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-30.png
# shape: 250 x 250
#
# 74
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-31.png
# shape: 250 x 250
#
# 75
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-32.png
# shape: 250 x 250
#
# 76
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-33.png
# shape: 250 x 250
#
# 77
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-34.png
# shape: 250 x 250
#
# 78
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-35.png
# shape: 250 x 250
#
# 79
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-36.png
# shape: 250 x 250
#
# 80
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-37.png
# shape: 250 x 250
#
# 81
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-38.png
# shape: 250 x 250
#
# 82
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-39.png
# shape: 250 x 250
#
# 83
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-4.png
# shape: 250 x 250
#
# 84
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-40.png
# shape: 250 x 250
#
# 85
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-41.png
# shape: 250 x 250
#
# 86
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-42.png
# shape: 250 x 250
#
# 87
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-43.png
# shape: 250 x 250
#
# 88
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-44.png
# shape: 250 x 250
#
# 89
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-45.png
# shape: 250 x 250
#
# 90
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-46.png
# shape: 250 x 250
#
# 91
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-47.png
# shape: 250 x 250
#
# 92
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-48.png
# shape: 250 x 250
#
# 93
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-49.png
# shape: 250 x 250
#
# 94
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-5.png
# shape: 250 x 250
#
# 95
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-50.png
# shape: 250 x 250
#
# 96
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-6.png
# shape: 250 x 250
#
# 97
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-7.png
# shape: 250 x 250
#
# 98
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-8.png
# shape: 250 x 250
#
# 99
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\CT_NonCovid\Normal-9.png
# shape: 250 x 250
#
# 100
#
#
# --saved in C:/Users/hvard/Desktop/Project/EdgeDetectedImages_Test/NON-COVID--
#
#
#
# ---reading directory C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia---
#
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-1.png
# shape: 250 x 250
#
# 1
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-10.png
# shape: 250 x 250
#
# 2
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-11.png
# shape: 250 x 250
#
# 3
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-12.png
# shape: 250 x 250
#
# 4
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-13.png
# shape: 250 x 250
#
# 5
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-14.png
# shape: 250 x 250
#
# 6
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-15.png
# shape: 250 x 250
#
# 7
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-16.png
# shape: 250 x 250
#
# 8
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-17.png
# shape: 250 x 250
#
# 9
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-18.png
# shape: 250 x 250
#
# 10
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-19.png
# shape: 250 x 250
#
# 11
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-2.png
# shape: 250 x 250
#
# 12
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-20.png
# shape: 250 x 250
#
# 13
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-21.png
# shape: 250 x 250
#
# 14
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-22.png
# shape: 250 x 250
#
# 15
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-23.png
# shape: 250 x 250
#
# 16
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-24.png
# shape: 250 x 250
#
# 17
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-25.png
# shape: 250 x 250
#
# 18
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-26.png
# shape: 250 x 250
#
# 19
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-27.png
# shape: 250 x 250
#
# 20
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-28.png
# shape: 250 x 250
#
# 21
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-29.png
# shape: 250 x 250
#
# 22
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-3.png
# shape: 250 x 250
#
# 23
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-30.png
# shape: 250 x 250
#
# 24
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-31.png
# shape: 250 x 250
#
# 25
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-32.png
# shape: 250 x 250
#
# 26
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-33.png
# shape: 250 x 250
#
# 27
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-34.png
# shape: 250 x 250
#
# 28
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-35.png
# shape: 250 x 250
#
# 29
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-36.png
# shape: 250 x 250
#
# 30
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-37.png
# shape: 250 x 250
#
# 31
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-38.png
# shape: 250 x 250
#
# 32
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-39.png
# shape: 250 x 250
#
# 33
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-4.png
# shape: 250 x 250
#
# 34
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-40.png
# shape: 250 x 250
#
# 35
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-41.png
# shape: 250 x 250
#
# 36
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-42.png
# shape: 250 x 250
#
# 37
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-43.png
# shape: 250 x 250
#
# 38
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-44.png
# shape: 250 x 250
#
# 39
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-45.png
# shape: 250 x 250
#
# 40
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-46.png
# shape: 250 x 250
#
# 41
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-47.png
# shape: 250 x 250
#
# 42
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-48.png
# shape: 250 x 250
#
# 43
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-49.png
# shape: 250 x 250
#
# 44
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-5.png
# shape: 250 x 250
#
# 45
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-50.png
# shape: 250 x 250
#
# 46
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-6.png
# shape: 250 x 250
#
# 47
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-7.png
# shape: 250 x 250
#
# 48
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-8.png
# shape: 250 x 250
#
# 49
# reading file---> C:\Users\hvard\Desktop\Project\Test_Covid\Pnemonia\Viral Pneumonia-9.png
# shape: 250 x 250
#
# 50
#
#
# --saved in C:/Users/hvard/Desktop/Project/EdgeDetectedImages_Test/Pnemonia--
#
#
# ---edge detection completed--
